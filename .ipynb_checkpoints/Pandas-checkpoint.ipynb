# %% [markdown]
# # pandas

# %% [markdown]
# - pandas is fast,powerful,flexible and easy to use open source data analysis and manipulation tool
# - pandas is a python library
# - pandas is used to analyze data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('timezone.csv')

# %%
df
# Out:
#                   Value        Label           Group
# 0        Africa/Abidjan      Abidjan          Africa
# 1          Africa/Accra        Accra          Africa
# 2    Africa/Addis_Ababa  Addis Ababa          Africa
# 3        Africa/Algiers      Algiers          Africa
# 4         Africa/Asmara       Asmara          Africa
# ..                  ...          ...             ...
# 476              UTC+12       UTC+12  Manual Offsets
# 477           UTC+12.75    UTC+12:45  Manual Offsets
# 478              UTC+13       UTC+13  Manual Offsets
# 479           UTC+13.75    UTC+13:45  Manual Offsets
# 480              UTC+14       UTC+14  Manual Offsets
#
# [481 rows x 3 columns]

# %%
df.head() #by default takes 5 as an input value
# Out:
#                 Value        Label   Group
# 0      Africa/Abidjan      Abidjan  Africa
# 1        Africa/Accra        Accra  Africa
# 2  Africa/Addis_Ababa  Addis Ababa  Africa
# 3      Africa/Algiers      Algiers  Africa
# 4       Africa/Asmara       Asmara  Africa

# %%
df.head(10)
# Out:
#                 Value        Label   Group
# 0      Africa/Abidjan      Abidjan  Africa
# 1        Africa/Accra        Accra  Africa
# 2  Africa/Addis_Ababa  Addis Ababa  Africa
# 3      Africa/Algiers      Algiers  Africa
# 4       Africa/Asmara       Asmara  Africa
# 5       Africa/Bamako       Bamako  Africa
# 6       Africa/Bangui       Bangui  Africa
# 7       Africa/Banjul       Banjul  Africa
# 8       Africa/Bissau       Bissau  Africa
# 9     Africa/Blantyre     Blantyre  Africa

# %%
df.tail()
# Out:
#          Value      Label           Group
# 476     UTC+12     UTC+12  Manual Offsets
# 477  UTC+12.75  UTC+12:45  Manual Offsets
# 478     UTC+13     UTC+13  Manual Offsets
# 479  UTC+13.75  UTC+13:45  Manual Offsets
# 480     UTC+14     UTC+14  Manual Offsets

# %%
df.tail(10)
# Out:
#          Value      Label           Group
# 471    UTC+9.5   UTC+9:30  Manual Offsets
# 472     UTC+10     UTC+10  Manual Offsets
# 473   UTC+10.5  UTC+10:30  Manual Offsets
# 474     UTC+11     UTC+11  Manual Offsets
# 475   UTC+11.5  UTC+11:30  Manual Offsets
# 476     UTC+12     UTC+12  Manual Offsets
# 477  UTC+12.75  UTC+12:45  Manual Offsets
# 478     UTC+13     UTC+13  Manual Offsets
# 479  UTC+13.75  UTC+13:45  Manual Offsets
# 480     UTC+14     UTC+14  Manual Offsets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   481 non-null    object
#  1   Label   481 non-null    object
#  2   Group   481 non-null    object
# dtypes: object(3)
# memory usage: 11.4+ KB

# %%
# describe the statistical information of the numerical columns 
df.describe()
# Out:
#          Value   Label    Group
# count      481     481      481
# unique     481     481       12
# top     UTC+14  UTC+14  America
# freq         1       1      147

# %%
df.columns #prints all the columns of the dataframe
# Out:
# Index(['Value', 'Label', 'Group'], dtype='object')

# %%
#transpose
df.T
# Out:
#                   0             1                   2               3    \
# Value  Africa/Abidjan  Africa/Accra  Africa/Addis_Ababa  Africa/Algiers
# Label         Abidjan         Accra         Addis Ababa         Algiers
# Group          Africa        Africa              Africa          Africa
#
#                  4              5              6              7    \
# Value  Africa/Asmara  Africa/Bamako  Africa/Bangui  Africa/Banjul
# Label         Asmara         Bamako         Bangui         Banjul
# Group         Africa         Africa         Africa         Africa
#
#                  8                9    ...             471             472  \
# Value  Africa/Bissau  Africa/Blantyre  ...         UTC+9.5          UTC+10
# Label         Bissau         Blantyre  ...        UTC+9:30          UTC+10
# Group         Africa           Africa  ...  Manual Offsets  Manual Offsets
#
#                   473             474             475             476  \
# ...

# %%
#sort your dataframe based on something for example in my case i will try label
df.sort_values('Label') #if i did this the original file will change so the solution is in the next cell
# Out:
#                    Value        Label      Group
# 0         Africa/Abidjan      Abidjan     Africa
# 1           Africa/Accra        Accra     Africa
# 52          America/Adak         Adak    America
# 2     Africa/Addis_Ababa  Addis Ababa     Africa
# 304   Australia/Adelaide     Adelaide  Australia
# ..                   ...          ...        ...
# 198  America/Yellowknife  Yellowknife    America
# 293         Asia/Yerevan      Yerevan       Asia
# 373        Europe/Zagreb       Zagreb     Europe
# 374    Europe/Zaporozhye   Zaporozhye     Europe
# 375        Europe/Zurich       Zurich     Europe
#
# [481 rows x 3 columns]

# %%
new_df=df.sort_values('Label')

# %%
new_df
# Out:
#                    Value        Label      Group
# 0         Africa/Abidjan      Abidjan     Africa
# 1           Africa/Accra        Accra     Africa
# 52          America/Adak         Adak    America
# 2     Africa/Addis_Ababa  Addis Ababa     Africa
# 304   Australia/Adelaide     Adelaide  Australia
# ..                   ...          ...        ...
# 198  America/Yellowknife  Yellowknife    America
# 293         Asia/Yerevan      Yerevan       Asia
# 373        Europe/Zagreb       Zagreb     Europe
# 374    Europe/Zaporozhye   Zaporozhye     Europe
# 375        Europe/Zurich       Zurich     Europe
#
# [481 rows x 3 columns]

# %%
df['Value'] # only prints the value column
# Out:
# 0          Africa/Abidjan
# 1            Africa/Accra
# 2      Africa/Addis_Ababa
# 3          Africa/Algiers
# 4           Africa/Asmara
#               ...
# 476                UTC+12
# 477             UTC+12.75
# 478                UTC+13
# 479             UTC+13.75
# 480                UTC+14
# Name: Value, Length: 481, dtype: object

# %%
df.Value
# Out:
# 0          Africa/Abidjan
# 1            Africa/Accra
# 2      Africa/Addis_Ababa
# 3          Africa/Algiers
# 4           Africa/Asmara
#               ...
# 476                UTC+12
# 477             UTC+12.75
# 478                UTC+13
# 479             UTC+13.75
# 480                UTC+14
# Name: Value, Length: 481, dtype: object

# %%
df['some new column'] = df['some column'] + 1000
# if i dont want to change the file itself then i assign it to a new variable
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'some column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['some new column'] = df['some column'] + 1000
# ...

# %%
df['random coulmn'] = 'good day'

# %%
df
# Out:
#                   Value        Label           Group random coulmn
# 0        Africa/Abidjan      Abidjan          Africa      good day
# 1          Africa/Accra        Accra          Africa      good day
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      good day
# 3        Africa/Algiers      Algiers          Africa      good day
# 4         Africa/Asmara       Asmara          Africa      good day
# ..                  ...          ...             ...           ...
# 476              UTC+12       UTC+12  Manual Offsets      good day
# 477           UTC+12.75    UTC+12:45  Manual Offsets      good day
# 478              UTC+13       UTC+13  Manual Offsets      good day
# 479           UTC+13.75    UTC+13:45  Manual Offsets      good day
# 480              UTC+14       UTC+14  Manual Offsets      good day
#
# [481 rows x 4 columns]

# %%
#how to access your rows

df[10:13] # 10 in inclusive 13 is exclusive
# Out:
#                  Value        Label   Group random coulmn
# 10  Africa/Brazzaville  Brazzaville  Africa      good day
# 11    Africa/Bujumbura    Bujumbura  Africa      good day
# 12        Africa/Cairo        Cairo  Africa      good day

# %%
df[20:26]
# Out:
#                   Value         Label   Group random coulmn
# 20      Africa/El_Aaiun      El Aaiun  Africa      good day
# 21      Africa/Freetown      Freetown  Africa      good day
# 22      Africa/Gaborone      Gaborone  Africa      good day
# 23        Africa/Harare        Harare  Africa      good day
# 24  Africa/Johannesburg  Johannesburg  Africa      good day
# 25          Africa/Juba          Juba  Africa      good day

# %%
new_df = df[df.Age>50] #hypothitically if we have an age in the file

# %%
#if i have null values how do i do that
df.fillna('amazing')
# Out:
#                   Value        Label           Group random coulmn
# 0        Africa/Abidjan      Abidjan          Africa      good day
# 1          Africa/Accra        Accra          Africa      good day
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      good day
# 3        Africa/Algiers      Algiers          Africa      good day
# 4         Africa/Asmara       Asmara          Africa      good day
# ..                  ...          ...             ...           ...
# 476              UTC+12       UTC+12  Manual Offsets      good day
# 477           UTC+12.75    UTC+12:45  Manual Offsets      good day
# 478              UTC+13       UTC+13  Manual Offsets      good day
# 479           UTC+13.75    UTC+13:45  Manual Offsets      good day
# 480              UTC+14       UTC+14  Manual Offsets      good day
#
# [481 rows x 4 columns]

# %%
df['Value'].fillna('amazing') #this if i want to handle the na values in Value column only
# Out:
# 0          Africa/Abidjan
# 1            Africa/Accra
# 2      Africa/Addis_Ababa
# 3          Africa/Algiers
# 4           Africa/Asmara
#               ...
# 476                UTC+12
# 477             UTC+12.75
# 478                UTC+13
# 479             UTC+13.75
# 480                UTC+14
# Name: Value, Length: 481, dtype: object

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 481 entries, 0 to 375
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   481 non-null    object
#  1   Label   481 non-null    object
#  2   Group   481 non-null    object
# dtypes: object(3)
# memory usage: 15.0+ KB

# %%
# remove columns
new_df.pop('Group')
# Out:
# 0         Africa
# 1         Africa
# 52       America
# 2         Africa
# 304    Australia
#          ...
# 198      America
# 293         Asia
# 373       Europe
# 374       Europe
# 375       Europe
# Name: Group, Length: 481, dtype: object

# %%
new_df
# Out:
#                    Value        Label
# 0         Africa/Abidjan      Abidjan
# 1           Africa/Accra        Accra
# 52          America/Adak         Adak
# 2     Africa/Addis_Ababa  Addis Ababa
# 304   Australia/Adelaide     Adelaide
# ..                   ...          ...
# 198  America/Yellowknife  Yellowknife
# 293         Asia/Yerevan      Yerevan
# 373        Europe/Zagreb       Zagreb
# 374    Europe/Zaporozhye   Zaporozhye
# 375        Europe/Zurich       Zurich
#
# [481 rows x 2 columns]

# %%
new_df.drop('Value',axis=1)
# Out:
#            Label
# 0        Abidjan
# 1          Accra
# 52          Adak
# 2    Addis Ababa
# 304     Adelaide
# ..           ...
# 198  Yellowknife
# 293      Yerevan
# 373       Zagreb
# 374   Zaporozhye
# 375       Zurich
#
# [481 rows x 1 columns]

# %%
new_df
# Out:
#                    Value        Label
# 0         Africa/Abidjan      Abidjan
# 1           Africa/Accra        Accra
# 52          America/Adak         Adak
# 2     Africa/Addis_Ababa  Addis Ababa
# 304   Australia/Adelaide     Adelaide
# ..                   ...          ...
# 198  America/Yellowknife  Yellowknife
# 293         Asia/Yerevan      Yerevan
# 373        Europe/Zagreb       Zagreb
# 374    Europe/Zaporozhye   Zaporozhye
# 375        Europe/Zurich       Zurich
#
# [481 rows x 2 columns]

# %%
# there is an apply method that i can use on data

# %%
# how to drop null values
df.dropna()
# Out:
#                   Value        Label           Group random coulmn
# 0        Africa/Abidjan      Abidjan          Africa      good day
# 1          Africa/Accra        Accra          Africa      good day
# 2    Africa/Addis_Ababa  Addis Ababa          Africa      good day
# 3        Africa/Algiers      Algiers          Africa      good day
# 4         Africa/Asmara       Asmara          Africa      good day
# ..                  ...          ...             ...           ...
# 476              UTC+12       UTC+12  Manual Offsets      good day
# 477           UTC+12.75    UTC+12:45  Manual Offsets      good day
# 478              UTC+13       UTC+13  Manual Offsets      good day
# 479           UTC+13.75    UTC+13:45  Manual Offsets      good day
# 480              UTC+14       UTC+14  Manual Offsets      good day
#
# [481 rows x 4 columns]

# %% [markdown]
# # Concat & merging

# %%
#if i have df1 and df2 and i want to concatenate them then it will look like this
result = pd.concat([df1,df2])

# %%
merge_df = pd.merge(df1,df2,on='the thing you want in common', how='outer') 
#how determines if it is inner-our=ter-left or right join

# %% [markdown]
# ## loc vs iloc

# %% [markdown]
# the main distinction between the two methods is:
# - loc gets rows (and/or columns) with particular labels
# - iloc gets rows (and/or columns) at integer locations

# %%
s = pd.Series(list("abcdef"),index=[49,48,47,0,1,2])
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s.loc[0] #value at index label 0
# Out:
# 'd'

# %%
s.iloc[0] #value at index location 0
# Out:
# 'a'

# %%
s.loc[0:1] # 1 here is inclusive
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:2] # 2 here is exclusive so we increase by one when we need smth
# Out:
# 49    a
# 48    b
# dtype: object
